# %% [markdown]
# # 효율적인 자료 처리를 위한 파이썬 표준 모듈
# 효율적인 복합 자료형 자료의 처리를 위해 알아두면 좋은 파이썬 표준 모듈 몇 가지를 소개한다.
#
# ## collections
# 전산과학에서 컬렉션(collection), 또는 컨테이너(container)라 함은 복수의 데이터 항목이 한 덩어리로 묶인 추상적인 자료형을 말한다. 파이썬의 딕셔너리, 리스트, 세트, 튜플은 모두 이러한 컬렉션의 예이다. 이들 컬렉션은 다양한 형태의 데이터의 표현에 유용하게 쓰인다. 한편 표준 라이브러리 모듈 가운데 하나인 collections 모듈은 특화된 컬렉션들을 제공한다. 이 가운데 몇 가지를 소개한다.

# %% [markdown]
# >https://en.wikipedia.org/wiki/Collection_(abstract_data_type) 참조.

# %% [markdown]
# ### `Counter`
# `Counter` 클래스는 빈도 계수를 위해 특화된 딕셔너리이다. 다음의 예제를 살펴보자.

# %%
# Counter 클래스를 이용한 어휘 빈도 계수
from collections import Counter

word_counter = Counter()   # 모든 key의 value의초기값이 0으로 셋팅되어 있다.

a_string = "무 배추 상추 고구마 무 상추 감사 양파 상추 파 가지 오이 토마토 가지 상추"
words = a_string.split()  # string to list

for word in words:
    word_counter[word] += 1
print(word_counter)

# %%
# 이것을 Counter()를 쓰지 않고 구현한다면..

word_counter_ = {}
word_set = set()

a_string = "무 배추 상추 고구마 무 상추 감사 양파 상추 파 가지 오이 토마토 가지 상추"
words = a_string.split()  # string to list

for word in words:
    if word in word_set:
        word_counter_[word] += 1
    else:
        word_counter_[word] = 1
    word_set.add(word)
print(word_counter_)

# %%
 word_counter.most_common()

# %%
for word, word_count in word_counter.most_common():   # most_common(n) : top n개를 보여준다.
    print("{}\t{}".format(word, word_count))

# %% [markdown]
# * `Counter` 클래스는 빈도 계수의 대상인 모든 객체에 대하여 기본 빈도값으로 0을 설정한다.
# * `most_common()` 메소드는 빈도 역순 정렬에 의한 데이터 항목 인출을 지원한다.
# * 다음과 같이 `update()` 메소드를 이용한 빈도 계수도 가능하다.

# %%
# Counter 클래스를 이용한 어휘 빈도 계수
from collections import Counter

word_counter = Counter()
a_string = "무 배추 상추 고구마 무 상추 감자 양파 상추 파 가지 오이 토마토 가지 상추"
words = a_string.split()

#for word in words:
#    word_counter[word] += 1

word_counter.update(words)
    
for word, word_count in word_counter.most_common():
    print("{}\t{}".format(word, word_count))

# %% [markdown]
# 빈도는 정수형의 자료이지만 `Counter` 객체는 다른 형의 자료도 값으로 저장할 수 있는 성질은 이용하여 빈도 계수 외의 작업에도 이용할 수 있다.

# %%
help(Counter)

# %% [markdown]
# ### `defaultdict`
# `defaultdict` 클래스는 앞서 설명한 `Counter` 클래스와 마찬가지로 특수한 딕셔너리로 값의 기본값이 자동으로 설정된다. 이러한 성질은 값의 형이 리스트나 딕셔너리, 또는 세트, 나아가 `defaultdict` 일 경우 매우 편리하다.

# %%
handset = {}
handset["Samsung"] = []  # value가 리스트나 딕셔너리, 세트 일때, 모든 key값에 대해 빈리스트로 초기화를 해주어야 한다...  key값이 미리 정해져있지 않다며 초기화는 그때그때...???
handset["Samsung"].append("Galaxy note4")
handset["Samsung"].append("Galaxy note8")
print(handset)
#handset["LG"]

# %%
from collections import defaultdict

foods = defaultdict(list)  # dictionary의 key에 대응하는 value가  list이다.
foods["과일"].append("사과")
foods["과일"].append("복숭아")
foods["채소"].append("토마토")
foods["채소"].append("오이")

print(foods)

# %% [markdown]
# * 위에서 보는 바와 같이 각 키에 대응하는 값의 리스트의 기본값인 빈 리스트로 설정된다.
# * 아래와 같이 딕셔너리에도 사용할 수 있다.

# %%
from collections import defaultdict

languages = defaultdict(dict)   # dictionary의 key에 대응하는 value가  dictionary 이다.
languages["파이썬"]["저자"] = "귀도 반 로섬"
languages["파이썬"]["유형"] = "스크립트 언어"
languages["파이썬"]["확장자"] = "py"
languages["고"]["저자"] = "로버트 그리즈머, 롭 파이크, 켄 톰슨"
languages["고"]["유형"] = "컴파일 언어"
languages["고"]["확장자"] = "go"
languages["R"]["저자"] = "S"
languages["R"]["유형"] = "스크립트 언어"
languages["R"]["확장자"] = "R"
print(languages)

# %% [markdown]
# ordered dict라는 것이 있다.
# 순서...

# %% [markdown]
# ## itertools
# itertools 모듈은 효과적인 반복문 실행을 위한 기재들을 제공한다. 이 기재들은 특히 중첩된 반복문을  사용해야 하는 경우에 유용하다.

# %%
from itertools import combinations

a_string = "무 배추 상추 고구마 무 상추 감자 양파 상추 파 가지 오이 토마토 가지 상추"
uniq_words = set(a_string.split())
print(uniq_words)
for word1, word2 in combinations(uniq_words, 2):   
    print(word1, word2)

# %% [markdown]
# * `combinations()` 함수는 주어진 이터러블 객체를 대상으로 주어진 정수 개의 가능한 조합을 생성한다.

# %% [markdown]
# >연관된 개념인 이터레이션, 이터러블, 이터레이터의 구분에 대해서 다음 URL의 스택오버플로우 답변을 보라. <http://stackoverflow.com/questions/9884132/what-exactly-are-pythons-iterator-iterable-and-iteration-protocols>

# %%
from itertools import permutations

a_string = "무 배추 상추 고구마 무 상추 감자 양파 상추 파 가지 오이 토마토 가지 상추"
uniq_words = set(a_string.split())

for word1, word2 in permutations(uniq_words, 2):
    print(word1, word2)

# %% [markdown]
# * `permutations()` 함수는 주어진 이터러블 객체를 대상으로 주어진 정수 개의 가능한 순열을 생성한다.

# %%
from itertools import product

fruits = ["사과", "배", "복숭아"]
vegitables = ["감자", "고구마"]

for fruit, vegitable in product(fruits, vegitables):
    print(fruit, vegitable)

# %% [markdown]
# * `product()` 함수는 주어진 이터러블 객체를 대상으로 데카르트 곱을 생성한다.

# %%
groupby?? 라는 함수도 유용하다.
module 내에 어떤 함수들이 있는지 확인할려면?

# %%
zip 함수도 유용한데, 유용한 변형들이 있다.

# %% [markdown]
# ## operator
# `operator` 모듈은 `+`, `-` 등의 연산자를 대신할 수 있는 함수들을 제공한다. 이 함수들은 함수적 프로그래밍에 매우 유용하다. 이 강좌에서는 `sorted()` 함수에 인자로 정렬 키를 지정하는 지정할 때에 이 모듈에서 제공하는 `itemgetter()` 함수를 이용한다. 이 함수의 사용법은 정렬을 다룰 때에 보인다.

# %% [markdown]
# # 텍스트 처리 실습
# 이제 텍스트 파일 처리를 경험해 보자.
#
# ## 정형 텍스트 파일 처리
# ### 예제 파일
# 예제로 다룰 데이터는 서울 열린 데이터 광장에서 제공하는 CSV 형식의 서울시 공공 와이파이 위치 정보 파일이다. 이 파일은 해당 데이터의 배포 페이지(<http://data.seoul.go.kr/openinf/sheetview.jsp?infId=OA-1218>)에서 내려받을 수 있다. 원래 파일의 이름은 `서울시 공공와이파이 위치정보.csv`인데 지난 강의에서 설명한 파일과 디렉토리 이름 주의 사항에 따라 `seoul_wifi.csv`로 이름을 바꾸어 `notebook` 디렉토리에 저장한다.
#
# >수강자들의 편의를 위해 `seoul_wifi.csv` 파일을 `data\textproc` 디렉토리에 넣어두었다. 이 파일을 복사하여 사용해도 된다.
#
# 이 파일을 앞서 설치한 노트패드++로 열어서 살펴보자. 마우스 오른쪽 버튼으로 클릭하여 "Edit with Notepad++"를 실행한다. 더블클릭하면 기본 연결 프로그램인 엑셀이 실행되므로 주의하자. 그러면 다음과 같이 표시된다.

# %% [markdown]
# ![노트패드++로 연 CSV 파일](figs/notepadpp-csv.png)

# %% [markdown]
# 위의 화면에서 파악할 수 있는 예제 파일의 주요 속성은 다음과 같다.
#
# * 이 파일은 일반 텍스트 파일(normal text file)이다. 노트패드++는 여러 프로그래밍 언어의 문법을 자동 인식한다. 자동 인식이 이루어지지 않으면 일반 텍스트 파일로 간주한다.
# * 이 파일은 길이가 247,330이다. 단위는 바이트이다. 이는 글자 수와는 다르다.
# * 이 파일에는 2,995 줄이 들어있다. 텍스트 파일의 중요한 특징 가운데 하나가 줄(line)로 구성된다는 것이다. 줄의 구분은 개행(New Line) 문자에 의해 이루어진다(개행 문자를 줄끝(EOL) 문자라고 부르기도 함).
# * 이 파일은 유닉스 형식의 줄바꿈 문자(LF)가 사용되었다. 윈도우에서는 CR과 LF 두 개의 문자로 줄바꿈을 나타내는 것이 표준이다. 따라서 이 파일을 메모장으로 열면 줄바꿈이 이루어지지 않은 채로 표시된다.
# * 이 파일은 UTF-8 방식으로 인코딩되었으며 바이트 순서 표식(BOM)이 달려있다. 윈도우의 표준 인코딩은 CP949이지만 UTF-8 인코딩 파일도 많은 프로그램에서 제대로 표시할 수 있다.   바이트 순서 표식은 UTF-8 인코딩 파일에서는 별로 의미가 없으므로 메뉴에서 **인코딩** -- **UTF-8 (BOM 없음)로 변환**을 실행하여 바이트 순서 표식을 없애고 저장하는 것이 좋다.
# * 이 파일은 CSV 파일이며, 각 필드는 큰따옴표(`"`)로 감싸여 있다.
# * 이 파일의 첫줄은 필드명을 나타내는 헤더이다.
#
# 텍스트 편집기로는 파일의 속성을 파악할 뿐만 아니라 여러 가지 전처리도 수행할 수 있다. 예를 들어 큰따옴표를 찾기 바꾸기를 이용하여 모두 없애고, 쉼표를 같은 방법으로 탭 문자로 바꾸면 CSV 파일을 TSV로 바꿀 수 있다.
#
# >더 안전하고 진보적인 방법은 `","` 문자열을 탭 문자로 바꾸고 정규식을 이용하여 줄 처음와 끝의 `"` 문자를 제거하는 것이다.
#
# ### 줄수 세기
# 텍스트 파일을 줄수는 다음과 같은 방법으로 셀 수 있다.

# %%
help(open)

# %% [markdown]
# # 텍스트파일 처리

# %%
# 텍스트 파일 줄수 세기
# 계수 변수(counter variable) 이용
input_file_name = "../data/textproc/seoul_wifi.csv"
line_count = 0

# window 한글인경우 encoding은 "cp949"로 지정해주면 된다.
with open(input_file_name, "r", encoding="utf-8-sig") as input_file:  # textfile은 line의 리스트로 본다.
    for line in input_file:   # line에는 줄바꿈 문자가 포함되어있다.
        # print(line)
        # line_count = line_count + 1
        line_count += 1
        
print("주어진 텍스트 파일 {}의 줄수는 {}입니다.".format(input_file_name, line_count))

# %% [raw]
# # 텍스트 파일 줄수 세기
# # 계수 변수(counter variable) 이용
# input_file_name = "../data/textproc/seoul_wifi.csv"
# line_count = 0
#
# # window 한글인경우 encoding은 "cp949"로 지정해주면 된다.
# with open(input_file_name, "r", encoding="utf-8-sig") as input_file:  # textfil의 핸들(input_file)은 line의 리스트로 본다.
#     text = input_file.read()  # 전체를 읽는 방법... 하나의 스트링에 저장.
#
# #lines = text.split("\n")   # 스트링을 라인단위로 끊어서, 리스트로
# lines = text.splitlines()
# print(len(lines))

# %% [markdown]
# file은 라인의 리스트로 볼수도 있는데, 이것은 for문에서 사용할 때 그렇다.
# file을 스트링으로 변환하고, 그것을 라인으로 split한다...

# %% [markdown]
# 위에 보인 코드에서 익힐 핵심은 다음과 같다.
#
# * 파일을 열 때에는 `open()` 함수를 사용한다. 인자로는 열 파일의 이름, 파일 오픈 모드, 그리고 인코딩을 넘겨준다. 예제 파일은 BOM을 지닌 utf-8 파일이므로 인코딩을 `utf-8-sig`로 지정한다. BOM이 없는 파일은 `utf-8`을 지정한다.
# * `open()` 함수를 `with` 문 안에서 사용하여 파일이 자동적으로 닫히도록 하는 것이 권장된다.
# * `for` 문을 파일 객체에 적용하면 파일의 내용을 줄 단위로 읽어 온다.
# * `+=` 연산자로 누계를 할 수 있다.

# %%
# CSV 라인을 TSV 라인으로 바꾸어 인쇄하기
input_file_name = "../data/textproc/seoul_wifi.csv"

with open(input_file_name, "r", encoding="utf-8-sig") as input_file:
    for csv_line in input_file:
        csv_line = csv_line.strip()  #스트링의 좌우공백과 \n을 없앤다.
        tsv_line = csv_line[1:-1]
        
        tsv_line = tsv_line.replace('","', "\t")
        print(tsv_line)

# %% [markdown]
# * 줄바꿈 문자를 제거하기 위해 `strip()` 메소드를 사용한다. 공백문자, 탭, 줄바꿈문자: whitespace
# * 각 줄의 맨 앞과 끝에 있는 큰따옴표를 없애기 위해 문자열 스플라이싱을 이용한다.
# * `replace()` 메소드를 이용하여 CSV 라인을 TSV 라인으로 바꾼다.

# %% [markdown]
# 헤더인 첫줄은 출력하지 않으려면 다음과 같이 할 수 있다.

# %%
# CSV 라인을 TSV 라인으로 변환하여 인쇄하기
# 헤더 건너 뛰기
input_file_name = "../data/textproc/seoul_wifi.csv"

with open(input_file_name, "r", encoding="utf-8-sig") as input_file:
    for line_num, csv_line in enumerate(input_file):
        if line_num == 0:
            continue
            
        csv_line = csv_line.strip()
        tsv_line = csv_line[1:-1]
        tsv_line = tsv_line.replace('","', "\t")
        print(tsv_line)

# %% [markdown]
# ### CSV 파일을 TSV 파일로 변환하기
# 위에서 보인 코드에 파일 출력을 덧붙이면 간단히 구현할 수 있다.

# %%
# CSV 파일을 TSV 파일로 변환하기
input_file_name = "../data/textproc/seoul_wifi.csv"
output_file_name = "../data/textproc/seoul_wifi.tsv"

with open(input_file_name, "r", encoding="utf-8-sig") as input_file, \
        open(output_file_name, "w", encoding="utf-8") as output_file:
    for line in input_file:
        line = line.strip()
        line = line[1:-1]
        line = line.replace('","', "\t")
        print(line, file=output_file)

# %% [markdown]
# * `with` 문에 `open()` 함수를 두 번 포함하여 입력 파일과 출력 파일을 동시에 열 수 있다.
# * 소스 코드의 한 줄이 너무 길어지면 역사선(back slash) 문자로 줄바꿈을 명시적으로 표시하고 줄바꿈을 할 수 있다. 이 때 줄바꿈이 되어 넘어간 내용은 들여쓰기를 한 단계 더 하여 실제 들여쓰기 된 코드와 구분하는 것이 좋다.

# %% [markdown]
# ### TSV 파일을 읽어서 데이터를 리스트에 저장하기
# TSV 파일에 저장된 데이터를 읽어서 리스트에 저장하는 일은 흔히 이루어지는 일이다. 각 줄 역시 데이터 항목이 구분된 리스트이므로 전체 데이터는 리스트의 리스트이다.

# %%
# TSV 파일을 읽어서 데이터를 리스트에 저장하기
input_file_name = "../data/textproc/seoul_wifi.tsv"
data = []

with open(input_file_name, "r", encoding="utf-8") as input_file:
    for line in input_file:
        line = line.strip()
        elems = line.split("\t")
        data.append(elems)

print(data)

# %% [markdown]
# 위에서 데이터를 저장할 때 사용한 자료 구조인 리스트의 리스트는 2차원 리스트로 볼 수 있다. 두 차원은 각각 2차원으로 표현되는 자료의 행(row)과 열(column)에 해당한다. 2차원 리스트의 개별 항목은 다음과 같이 2차원 인덱싱을 통하여 참조할 수 있다.

# %%
print(data[0][0])
print(data[2][5])

# %% [markdown]
# 이와 같은 2차원 자료 구조는 행과 열, 또는 레코드와 필드로 구성되는 전형적인 형태의 자료 처리에 널리 쓰인다.

# %% [markdown]
# ### TSV 파일을 읽어서 딕셔너리에 저장하기
# 2차원 자료를 저장할 때에 목적에 따라 딕셔너리를 이용할 수도 있다. 구체적으로는 딕셔너리의 딕셔너리를 이용할 수도 있고, 리스트의 딕셔너리를 사용할 수도 있다. 다음은 리스트의 딕셔너리를 이용한 예이다.

# %%
# TSV 파일을 읽어서 리스트의 딕셔너리에 저장하기

# 리스트의 딕셔너리 초기화
field_names = ["구명", "유형", "지역명", "설치위치(X좌표)", "설치위치(Y좌표)",  
               "설치기관(회사)"]
data = {}

for field_name in field_names:
    data[field_name] = []

# TSV 파일 읽어서 데이터 저장히기
input_file_name = "../data/textproc/seoul_wifi.tsv"

with open(input_file_name, "r", encoding="utf-8") as input_file:
    for line_num, line in list(enumerate(input_file))[:11]:
        if line_num == 0:
            continue
            
        line = line.strip()
        elems = line.split("\t")
        
        for elem, field_name in zip(elems, field_names):
            # l = data[field_name]
            # l.append(elem)
            # data[field_name] = l
            data[field_name].append(elem)
            
print(data)

# %%
list(enumerate([3,4,5,6,7,8]))

# %% [markdown]
# * 자료를 저장한 자료 구조는 리스트의 딕셔너리로 키는 컬럼 이름, 값은 자료 항목들을 담는 리스트이다.
# * 각 컬럼의 이름을 하드 코딩한다.
# * `zip()` 함수를 이용하여 각 컬럼의 값을 적절한 리스트에 추가한다.
#
# 컬럼 이름의 하드 코딩을 하지 않고 리스트의 초기화를 간단히 하는 코드를 아래에 보인다.

# %%
import collections

# default dict 초기화. value가 list, dict, set일때 사용할 것.
data = collections.defaultdict(list)

# TSV 파일 읽어서 데이터 저장히기
input_file_name = "../data/textproc/seoul_wifi.tsv"

with open(input_file_name, "r", encoding="utf-8") as input_file:
    for line_num, line in enumerate(input_file):
        line = line.strip()
        elems = line.split("\t")
        
        if line_num == 0:
            field_names = elems
            continue
            
        for elem, field_name in zip(elems, field_names):
            data[field_name].append(elem)
            
print(data)

# %% [markdown]
# * collections 모듈의 defaultdict 클래스를 사용한다.

# %% [markdown]
# ## JSON 파일 처리
#
# 우리는 앞서 대표적인 정형 텍스트 형식인 CSV와 TSV 형식의 파일 처리를 간략히 살펴보았다. 이들 형식과 함께 현업에서 많이 사용하는 형식으로 JSON(JavaScript Object Notation, <http://json.org>) 형식이 있다. 이름에서 알 수 있듯이 이 형식은 자바스크립트에서 유래한 것으로 CSV나 TSV보다는 다소 복잡하지만, 키와 값을 명시적으로 표기하여 이독성을 높일 수 있으며, 리스트 등의 내포 구조를 표현할 수 있는 등의 장점이 많아 널리 사용되고 있다.

# %% [markdown]
# ### JSON 파일
# 우리는 앞서 실습에서 CSV 형식의 서울시 공공 와이파이 위치 정보를 사용했는데, 데이터 배포 페이지(<http://data.seoul.go.kr/openinf/sheetview.jsp?tMenu=11&leftSrvType=S&infId=OA-1218>)에서는 JSON 형식의 파일도 제공한다. 이 파일을 내려 받아 편집기로 열어서 내용을 살펴보면 다음과 같다.

# %% [markdown]
# >이 파일을 내려받아 저장할 때 `seoul_wifi.json`과 같이 로만 알파벳으로 공백 없이 파일 이름을 바꾸어 저장하는 것을 잊지 말자. 강의참여자들의 편의를 위해 `data\textproc` 디렉토리에 해당 파일을 넣어 두었다.

# %% [markdown]
# ```json
# {
# "DESCRIPTION" : {"PLACE_NAME":"지역명","CATEGORY":"유형","INSTL_X":"설치위치(X좌표)","INSTL_Y":"설치위치(Y좌표)","GU_NM":"구명","INSTL_DIV":"설치기관(회사)"},
# "DATA" : [
# {"PLACE_NAME":"(재)서울산업통상진흥원","CATEGORY":"공공기관","INSTL_X":"127.0717546","INSTL_Y":"37.4955815","GU_NM":"강남구","INSTL_DIV":"LGU+"}, {"PLACE_NAME":"(재)서울산업통상진흥원서울신기술창업센타","CATEGORY":"공공기관","INSTL_X":"127.0380541","INSTL_Y":"37.4976121","GU_NM":"강남구","INSTL_DIV":"LGU+"},
# {"PLACE_NAME":"U강남도시관제센터","CATEGORY":"공공기관","INSTL_X":"127.0409920","INSTL_Y":"37.5084025","GU_NM":"강남구","INSTL_DIV":"강남구"},
# ...
# {"PLACE_NAME":"상봉동 거리","CATEGORY":"주요거리","INSTL_X":"127.0940500","INSTL_Y":"37.6043750","GU_NM":"중랑구","INSTL_DIV":"LGU+"}
# ]
# }
# ```

# %% [markdown]
# 잘 살펴보면 이 파일의 형식은 파이썬의 딕셔너리를 문자열로 표현한 형식과 똑같다. 즉, 전체가 하나의 딕셔너리이다. 이 JSON 파일의 최상위 키는 `DESCRIPTION`과 `DATA`이고, `DESCRIPTION`의 값은 영어 필드명을 키로, 한국어 필드명을 값으로 하는 딕셔너리이며, `DATA`의 값은 와이파이 설치 장소의 정보를 키와 값으로 나타낸 딕셔너리 형식의 개별 데이터 항목의 리스트이다.
#
# 이제 이 파일을 읽어서 조작해 보자.

# %%
# JSON 파일 읽어서 딕셔너리로 만들기
import json

file_name = "../data/textproc/seoul_wifi.json"

with open(file_name, "r", encoding="utf-8") as input_file:
    text = input_file.read()  # json 파일을 텍스트로 읽고(스트링으로 저장)
    
doc = json.loads(text)      # 스트링을 json객체로 만든다. dictionary로...
print(str(doc)[:500])
# Out:
# {'DESCRIPTION': {'PLACE_NAME': '지역명', 'CATEGORY': '유형', 'INSTL_X': '설치위치(X좌표)', 'INSTL_Y': '설치위치(Y좌표)', 'GU_NM': '구명', 'INSTL_DIV': '설치기관(회사)'}, 'DATA': [{'PLACE_NAME': '(재)서울산업통상진흥원', 'CATEGORY': '공공기관', 'INSTL_X': '127.0717546', 'INSTL_Y': '37.4955815', 'GU_NM': '강남구', 'INSTL_DIV': 'LGU+'}, {'PLACE_NAME': '(재)서울산업통상진흥원서울신기술창업센타', 'CATEGORY': '공공기관', 'INSTL_X': '127.0380541', 'INSTL_Y': '37.4976121', 'GU_NM': '강남구', 'INSTL_DIV': 'LGU+'}, {'PLACE_NAME': 'U강남도시관제센터', 'CATEGORY': '공공기관', 'INSTL_X'

# %%
type(doc)
# Out:
# dict

# %%
doc
# Out:
# {'DATA': [{'CATEGORY': '공공기관',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.0717546',
#    'INSTL_Y': '37.4955815',
#    'PLACE_NAME': '(재)서울산업통상진흥원'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.0380541',
#    'INSTL_Y': '37.4976121',
#    'PLACE_NAME': '(재)서울산업통상진흥원서울신기술창업센타'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '강남구',
#    'INSTL_DIV': '강남구',
#    'INSTL_X': '127.0409920',
#    'INSTL_Y': '37.5084025',
#    'PLACE_NAME': 'U강남도시관제센터'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '강남구',
#    'INSTL_DIV': '강남구',
#    'INSTL_X': '127.0642026',
#    'INSTL_Y': '37.4939383',
#    'PLACE_NAME': '강남구의회'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '강남구',
#    'INSTL_DIV': '강남구',
#    'INSTL_X': '127.0475020',
#    'INSTL_Y': '37.5173050',
#    'PLACE_NAME': '강남구청'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '강남구',
#    'INSTL_DIV': '상수도사업본부',
#    'INSTL_X': '127.0471233',
#    'INSTL_Y': '37.4833851',
#    'PLACE_NAME': '강남수도사업소'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.0672394',
#    'INSTL_Y': '37.5084197',
#    'PLACE_NAME': '강남운전면허시험장(대치)'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '강남구',
#    'INSTL_DIV': '강남구',
#    'INSTL_X': '127.0384706',
#    'INSTL_Y': '37.4909267',
#    'PLACE_NAME': '강남인터넷방송국'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.0507291',
#    'INSTL_Y': '37.5045560',
#    'PLACE_NAME': '강남종합고용지원센터'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.0307472',
#    'INSTL_Y': '37.5007248',
#    'PLACE_NAME': '과학기술회관'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.0528667',
#    'INSTL_Y': '37.4890937',
#    'PLACE_NAME': '군인공제회관'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0308650',
#    'INSTL_Y': '37.5004619',
#    'PLACE_NAME': '군인공제회관 회원지원센터(도곡동)'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.0476601',
#    'INSTL_Y': '37.5037628',
#    'PLACE_NAME': '기술신용보증기금'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '강남구',
#    'INSTL_DIV': '서울시',
#    'INSTL_X': '127.0879073',
#    'INSTL_Y': '37.47976015',
#    'PLACE_NAME': '아동복지센터'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0298608',
#    'INSTL_Y': '37.5113394',
#    'PLACE_NAME': '논현개나리공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0251180',
#    'INSTL_Y': '37.5085141',
#    'PLACE_NAME': '논현까치공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.022421',
#    'INSTL_Y': '37.5126222',
#    'PLACE_NAME': '논현은행나무공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.082306',
#    'INSTL_Y': '37.491938',
#    'PLACE_NAME': '대청공원주변'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0443385',
#    'INSTL_Y': '37.4849477',
#    'PLACE_NAME': '도곡목련공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.046824',
#    'INSTL_Y': '37.4845582',
#    'PLACE_NAME': '독골근린공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.046503',
#    'INSTL_Y': '37.485075',
#    'PLACE_NAME': '독설공원주변'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.047111',
#    'INSTL_Y': '37.481655',
#    'PLACE_NAME': '양재천변'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.054016',
#    'INSTL_Y': '37.487003',
#    'PLACE_NAME': '양재천변'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.062251',
#    'INSTL_Y': '37.489893',
#    'PLACE_NAME': '양재천변'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.069833',
#    'INSTL_Y': '37.49615',
#    'PLACE_NAME': '양재천변'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.069855',
#    'INSTL_Y': '37.496133',
#    'PLACE_NAME': '양재천변'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.070024',
#    'INSTL_Y': '37.494357',
#    'PLACE_NAME': '양재천변'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.072345',
#    'INSTL_Y': '37.499309',
#    'PLACE_NAME': '양재천변'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.074404',
#    'INSTL_Y': '37.498152',
#    'PLACE_NAME': '양재천변'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.074621',
#    'INSTL_Y': '37.500053',
#    'PLACE_NAME': '양재천변'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0774436',
#    'INSTL_Y': '37.4899302',
#    'PLACE_NAME': '일원2동 늘푸른공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.085556',
#    'INSTL_Y': '37.4914386',
#    'PLACE_NAME': '일원목련공원'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.0469916',
#    'INSTL_Y': '37.5137356',
#    'PLACE_NAME': '강남도서관'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.10525',
#    'INSTL_Y': '37.4891013',
#    'PLACE_NAME': '강남스포츠문화센터'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.0540445',
#    'INSTL_Y': '37.52052897',
#    'PLACE_NAME': '강남청소년수련관'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.0637690',
#    'INSTL_Y': '37.4829604',
#    'PLACE_NAME': '개포도서관'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0300534',
#    'INSTL_Y': '37.5022354',
#    'PLACE_NAME': '국기원(역삼동) 1F'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0372',
#    'INSTL_Y': '37.5173333',
#    'PLACE_NAME': '논현도서관'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.0669398',
#    'INSTL_Y': '37.50001348',
#    'PLACE_NAME': '대치평생학습관'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': '강남구',
#    'INSTL_X': '127.0389239',
#    'INSTL_Y': '37.4881818',
#    'PLACE_NAME': '도곡정보문화도서관'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0526190',
#    'INSTL_Y': '37.5256160',
#    'PLACE_NAME': '새벽집'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0471830',
#    'INSTL_Y': '37.5262850',
#    'PLACE_NAME': '아트스페이스'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.0357833',
#    'INSTL_Y': '37.52729298',
#    'PLACE_NAME': '압구정평생학습관'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.0500818',
#    'INSTL_Y': '37.4975477',
#    'PLACE_NAME': '역삼동 문화센터'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.0410313',
#    'INSTL_Y': '37.49393789',
#    'PLACE_NAME': '역삼청소년수련관'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0820634',
#    'INSTL_Y': '37.4927971',
#    'PLACE_NAME': '일원청소년독서실'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0578185',
#    'INSTL_Y': '37.4997257',
#    'PLACE_NAME': '즐거운도서관'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0440600',
#    'INSTL_Y': '37.5276470',
#    'PLACE_NAME': '청담고'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0456630',
#    'INSTL_Y': '37.5273600',
#    'PLACE_NAME': '청담초'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.0464205',
#    'INSTL_Y': '37.519128',
#    'PLACE_NAME': '청담평생학습관'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': '강남구',
#    'INSTL_X': '127.0464450',
#    'INSTL_Y': '37.5191080',
#    'PLACE_NAME': '청담평생학습관'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.0587979',
#    'INSTL_Y': '37.5124637',
#    'PLACE_NAME': '코엑스전시장(몰)'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': '강남구',
#    'INSTL_X': '127.0642072',
#    'INSTL_Y': '37.5022848',
#    'PLACE_NAME': '행복한도서관'},
#   {'CATEGORY': '버스승차대',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.026214',
#    'INSTL_Y': '37.497742',
#    'PLACE_NAME': '강남역사거리'},
#   {'CATEGORY': '버스승차대',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.029331',
#    'INSTL_Y': '37.498251',
#    'PLACE_NAME': '강남역사거리'},
#   {'CATEGORY': '버스승차대',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.050539',
#    'INSTL_Y': '37.504728',
#    'PLACE_NAME': '선릉역'},
#   {'CATEGORY': '버스승차대',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.022059',
#    'INSTL_Y': '37.517435',
#    'PLACE_NAME': '신사사거리'},
#   {'CATEGORY': '버스승차대',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.061086',
#    'INSTL_Y': '37.511989',
#    'PLACE_NAME': '코엑스동문.한국무역센타'},
#   {'CATEGORY': '보건시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.0422041',
#    'INSTL_Y': '37.51628601',
#    'PLACE_NAME': '강남구 보건소'},
#   {'CATEGORY': '보건시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0422835',
#    'INSTL_Y': '37.5163931',
#    'PLACE_NAME': '보건소'},
#   {'CATEGORY': '보건시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': '강남구',
#    'INSTL_X': '127.1054661',
#    'INSTL_Y': '37.4888050',
#    'PLACE_NAME': '보건소분소'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.107019',
#    'INSTL_Y': '37.48696465',
#    'PLACE_NAME': '강남구 직업재활센터'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.0901293',
#    'INSTL_Y': '37.483816',
#    'PLACE_NAME': '강남구 청소년상담복지센터'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.0516077',
#    'INSTL_Y': '37.51698596',
#    'PLACE_NAME': '강남노인종합복지관'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.0746666',
#    'INSTL_Y': '37.49234151',
#    'PLACE_NAME': '강남장애인복지관'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.0543227',
#    'INSTL_Y': '37.5032219',
#    'PLACE_NAME': '대치노인복지센터'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.1192729',
#    'INSTL_Y': '37.47058113',
#    'PLACE_NAME': '성모자애복지관'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0382173',
#    'INSTL_Y': '37.5235584',
#    'PLACE_NAME': '압구정노인복지센터'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0934479',
#    'INSTL_Y': '37.48472679',
#    'PLACE_NAME': '태화기독사회복지관'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.07517',
#    'INSTL_Y': '37.49256193',
#    'PLACE_NAME': '하상장애인복지관'},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.020569',
#    'INSTL_Y': '37.518774',
#    'PLACE_NAME': '강남시장'},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.0280696',
#    'INSTL_Y': '37.4986144 ',
#    'PLACE_NAME': '강남역 지하상가'},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.023881',
#    'INSTL_Y': '37.509119',
#    'PLACE_NAME': '영동전통시장 '},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.057737',
#    'INSTL_Y': '37.522519',
#    'PLACE_NAME': '청담삼익시장'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': '강남구',
#    'INSTL_X': '127.0521441',
#    'INSTL_Y': '37.5160727',
#    'PLACE_NAME': '강남문화재단'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0574661',
#    'INSTL_Y': '37.4818898',
#    'PLACE_NAME': '개포1동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0689523',
#    'INSTL_Y': '37.4897723',
#    'PLACE_NAME': '개포2동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0516374',
#    'INSTL_Y': '37.4788183',
#    'PLACE_NAME': '개포4동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0566765',
#    'INSTL_Y': '37.4931401',
#    'PLACE_NAME': '대치1동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': '강남구',
#    'INSTL_X': '127.0642072',
#    'INSTL_Y': '37.5022848',
#    'PLACE_NAME': '대치2동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': '강남구',
#    'INSTL_X': '127.0577874',
#    'INSTL_Y': '37.4998660',
#    'PLACE_NAME': '대치4동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0387883',
#    'INSTL_Y': '37.4885147',
#    'PLACE_NAME': '도곡1동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0464338',
#    'INSTL_Y': '37.4837425',
#    'PLACE_NAME': '도곡2동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0459500',
#    'INSTL_Y': '37.5112000',
#    'PLACE_NAME': '삼성2동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1069322',
#    'INSTL_Y': '37.4690635',
#    'PLACE_NAME': '세곡동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1049103',
#    'INSTL_Y': '37.4889102',
#    'PLACE_NAME': '수서동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': '강남구',
#    'INSTL_X': '127.0333574',
#    'INSTL_Y': '37.4954841',
#    'PLACE_NAME': '역삼1동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': '강남구',
#    'INSTL_X': '127.0468034',
#    'INSTL_Y': '37.4959674',
#    'PLACE_NAME': '역삼2동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0879629',
#    'INSTL_Y': '37.4918390',
#    'PLACE_NAME': '일원1동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0737224',
#    'INSTL_Y': '37.4922048',
#    'PLACE_NAME': '일원2동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0864633',
#    'INSTL_Y': '37.4833485',
#    'PLACE_NAME': '일원본동 주민센터 인터넷카페'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0864633',
#    'INSTL_Y': '37.4833485',
#    'PLACE_NAME': '일원본동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0493000',
#    'INSTL_Y': '37.5251083',
#    'PLACE_NAME': '청담동주민센터'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0365098',
#    'INSTL_Y': '37.5023604',
#    'PLACE_NAME': 'GS타워'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0470764',
#    'INSTL_Y': '37.5035372',
#    'PLACE_NAME': 'I타워'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0376810',
#    'INSTL_Y': '37.5026430',
#    'PLACE_NAME': 'LG아트센터'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0226800',
#    'INSTL_Y': '37.5176900',
#    'PLACE_NAME': '가로수길'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0247900',
#    'INSTL_Y': '37.5181610',
#    'PLACE_NAME': '가로수길'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0263906',
#    'INSTL_Y': '37.5016210',
#    'PLACE_NAME': '강남CGV앞'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0191464',
#    'INSTL_Y': '37.5194649',
#    'PLACE_NAME': '강남대로 648'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0269926',
#    'INSTL_Y': '37.502213',
#    'PLACE_NAME': '강남대로102길 15'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0237475',
#    'INSTL_Y': '37.5076678',
#    'PLACE_NAME': '강남대로122길 5'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0271191',
#    'INSTL_Y': '37.5088742',
#    'PLACE_NAME': '강남대로122길 50'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0318546',
#    'INSTL_Y': '37.4917341',
#    'PLACE_NAME': '강남대로66길 14'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0274025',
#    'INSTL_Y': '37.4993634',
#    'PLACE_NAME': '강남역 11번출구'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0272590',
#    'INSTL_Y': '37.4993290',
#    'PLACE_NAME': '강남역주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0294310',
#    'INSTL_Y': '37.4948010',
#    'PLACE_NAME': '강남역주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0374260',
#    'INSTL_Y': '37.4991554',
#    'PLACE_NAME': '강남파이낸스센터'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0375250',
#    'INSTL_Y': '37.4992630',
#    'PLACE_NAME': '강남파이낸스센터'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0690671',
#    'INSTL_Y': '37.4897734',
#    'PLACE_NAME': '개포로 511'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.052966',
#    'INSTL_Y': '37.480757',
#    'PLACE_NAME': '개포로 주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.078284',
#    'INSTL_Y': '37.495475',
#    'PLACE_NAME': '개포로 주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.080134',
#    'INSTL_Y': '37.4904527',
#    'PLACE_NAME': '개포로110길 46'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0422290',
#    'INSTL_Y': '37.5043500',
#    'PLACE_NAME': '공무원연금관리공단'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0266530',
#    'INSTL_Y': '37.5218160',
#    'PLACE_NAME': '공영주차장'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.029571',
#    'INSTL_Y': '37.50202265',
#    'PLACE_NAME': '과학기술원(국기원)'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.030154',
#    'INSTL_Y': '37.50100337',
#    'PLACE_NAME': '과학기술원(국기원)'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0529640',
#    'INSTL_Y': '37.4807390',
#    'PLACE_NAME': '구룡초 후문'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0696820',
#    'INSTL_Y': '37.4961670',
#    'PLACE_NAME': '그린공원'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.061956',
#    'INSTL_Y': '37.494889',
#    'PLACE_NAME': '남부순환로 주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0470625',
#    'INSTL_Y': '37.4851142',
#    'PLACE_NAME': '남부순환로378길 29'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0284610',
#    'INSTL_Y': '37.5115706',
#    'PLACE_NAME': '논현1동'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.025118',
#    'INSTL_Y': '37.5085141',
#    'PLACE_NAME': '논현1동 162-11'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.022462',
#    'INSTL_Y': '37.5126379',
#    'PLACE_NAME': '논현1동 47-13'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0372130',
#    'INSTL_Y': '37.5173420',
#    'PLACE_NAME': '논현2동'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0237475',
#    'INSTL_Y': '37.5076678',
#    'PLACE_NAME': '논현동맛의거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0270185',
#    'INSTL_Y': '37.5042573',
#    'PLACE_NAME': '논현로105길 91'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0298608',
#    'INSTL_Y': '37.5113394',
#    'PLACE_NAME': '논현로123길 19'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0235933',
#    'INSTL_Y': '37.5221809',
#    'PLACE_NAME': '논현로161길 59'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0447294',
#    'INSTL_Y': '37.4847123',
#    'PLACE_NAME': '논현로34길 34'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0276910',
#    'INSTL_Y': '37.5230290',
#    'PLACE_NAME': '논현로주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0285250',
#    'INSTL_Y': '37.5232610',
#    'PLACE_NAME': '논현로주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0599260',
#    'INSTL_Y': '37.4939680',
#    'PLACE_NAME': '단대부고'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0783010',
#    'INSTL_Y': '37.4958260',
#    'PLACE_NAME': '대진공원'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0547593',
#    'INSTL_Y': '37.5043924',
#    'PLACE_NAME': '대치4동 894'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0619263',
#    'INSTL_Y': '37.4949274',
#    'PLACE_NAME': '대치동 212'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0620157',
#    'INSTL_Y': '37.4963374',
#    'PLACE_NAME': '대치동 449'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0571673',
#    'INSTL_Y': '37.4895627',
#    'PLACE_NAME': '대치동 501'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.068215',
#    'INSTL_Y': '37.5041266',
#    'PLACE_NAME': '대치동 78-24'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.050684',
#    'INSTL_Y': '37.503111',
#    'PLACE_NAME': '대치동 거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.051855',
#    'INSTL_Y': '37.503561',
#    'PLACE_NAME': '대치동 거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0517226',
#    'INSTL_Y': '37.5037458',
#    'PLACE_NAME': '대치동 산등성길'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0527912',
#    'INSTL_Y': '37.5038166',
#    'PLACE_NAME': '대치동 산등성길'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0547593',
#    'INSTL_Y': '37.5043924',
#    'PLACE_NAME': '대치동 산등성길'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0330173',
#    'INSTL_Y': '37.4919845',
#    'PLACE_NAME': '도곡로3길 26'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0351050',
#    'INSTL_Y': '37.5236490',
#    'PLACE_NAME': '도산공원'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0433987',
#    'INSTL_Y': '37.52315',
#    'PLACE_NAME': '도산대로 434'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0235479',
#    'INSTL_Y': '37.5213835',
#    'PLACE_NAME': '도산대로17길 45'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0194442',
#    'INSTL_Y': '37.5208045',
#    'PLACE_NAME': '도산대로1길 62'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.035678',
#    'INSTL_Y': '37.522384',
#    'PLACE_NAME': '도산대로주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.038964',
#    'INSTL_Y': '37.52346',
#    'PLACE_NAME': '도산대로주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0415160',
#    'INSTL_Y': '37.5232690',
#    'PLACE_NAME': '도산대로주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0446400',
#    'INSTL_Y': '37.5236650',
#    'PLACE_NAME': '도산대로주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0463240',
#    'INSTL_Y': '37.4851770',
#    'PLACE_NAME': '독설공원'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0482740',
#    'INSTL_Y': '37.5056320',
#    'PLACE_NAME': '비전빌딩'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.057926',
#    'INSTL_Y': '37.489359',
#    'PLACE_NAME': '삼성로 주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.06207',
#    'INSTL_Y': '37.496308',
#    'PLACE_NAME': '삼성로 주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0629830',
#    'INSTL_Y': '37.5100330',
#    'PLACE_NAME': '삼성역7번출구'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0640200',
#    'INSTL_Y': '37.5093540',
#    'PLACE_NAME': '삼성역8번출구'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0606000',
#    'INSTL_Y': '37.5074200',
#    'PLACE_NAME': '삼성역주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0329080',
#    'INSTL_Y': '37.5243350',
#    'PLACE_NAME': '삼원가든'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0293287',
#    'INSTL_Y': '37.4932589',
#    'PLACE_NAME': '서초동 1329-8'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.042015',
#    'INSTL_Y': '37.5206286',
#    'PLACE_NAME': '선릉로 742'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0406456',
#    'INSTL_Y': '37.5214262',
#    'PLACE_NAME': '선릉로 748'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0398908',
#    'INSTL_Y': '37.5246112',
#    'PLACE_NAME': '선릉로 816'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0402472',
#    'INSTL_Y': '37.525842',
#    'PLACE_NAME': '선릉로 828'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0527912',
#    'INSTL_Y': '37.5038166',
#    'PLACE_NAME': '선릉로86길 38'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0503130',
#    'INSTL_Y': '37.5046560',
#    'PLACE_NAME': '선릉역1번출구'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0475987',
#    'INSTL_Y': '37.5044788',
#    'PLACE_NAME': '선릉역5번출구'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0473759',
#    'INSTL_Y': '37.50375711',
#    'PLACE_NAME': '선릉역주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0475335',
#    'INSTL_Y': '37.50444242',
#    'PLACE_NAME': '선릉역주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0483869',
#    'INSTL_Y': '37.50540755',
#    'PLACE_NAME': '선릉역주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0501145',
#    'INSTL_Y': '37.50462014',
#    'PLACE_NAME': '선릉역주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0504000',
#    'INSTL_Y': '37.5054630',
#    'PLACE_NAME': '선릉역주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0526740',
#    'INSTL_Y': '37.5059090',
#    'PLACE_NAME': '선릉역주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0332090',
#    'INSTL_Y': '37.5264330',
#    'PLACE_NAME': '소망교회'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0254320',
#    'INSTL_Y': '37.5232580',
#    'PLACE_NAME': '신구초'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0227814',
#    'INSTL_Y': '37.5240101',
#    'PLACE_NAME': '신사동'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0223027',
#    'INSTL_Y': '37.5232517',
#    'PLACE_NAME': '신사동 532-12'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0228861',
#    'INSTL_Y': '37.5200036',
#    'PLACE_NAME': '신사동 535-19'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0229598',
#    'INSTL_Y': '37.5217557',
#    'PLACE_NAME': '신사동 546-6'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0260553',
#    'INSTL_Y': '37.5205444',
#    'PLACE_NAME': '신사동 558'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0257990',
#    'INSTL_Y': '37.5227330',
#    'PLACE_NAME': '신사목련공원'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0193790',
#    'INSTL_Y': '37.5176290',
#    'PLACE_NAME': '신사역6번출구'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0197920',
#    'INSTL_Y': '37.5181930',
#    'PLACE_NAME': '신사역6번출구'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0201270',
#    'INSTL_Y': '37.5170750',
#    'PLACE_NAME': '신사역7번출구'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0210210',
#    'INSTL_Y': '37.5169770',
#    'PLACE_NAME': '신사역8번출구'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0208310',
#    'INSTL_Y': '37.5163740',
#    'PLACE_NAME': '신사역주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0220360',
#    'INSTL_Y': '37.5168940',
#    'PLACE_NAME': '신사역주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0307130',
#    'INSTL_Y': '37.5306420',
#    'PLACE_NAME': '압구정동'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0206782',
#    'INSTL_Y': '37.526676',
#    'PLACE_NAME': '압구정동 390'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0408053',
#    'INSTL_Y': '37.5307491',
#    'PLACE_NAME': '압구정동 492'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0397797',
#    'INSTL_Y': '37.531255',
#    'PLACE_NAME': '압구정동 497'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0363114',
#    'INSTL_Y': '37.5320544',
#    'PLACE_NAME': '압구정동 498'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0437228',
#    'INSTL_Y': '37.5301241',
#    'PLACE_NAME': '압구정동 505'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0418415',
#    'INSTL_Y': '37.5304165',
#    'PLACE_NAME': '압구정동 509'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0294582',
#    'INSTL_Y': '37.5273934',
#    'PLACE_NAME': '압구정로 204'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0328333',
#    'INSTL_Y': '37.5287015',
#    'PLACE_NAME': '압구정로 228'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0395133',
#    'INSTL_Y': '37.5278456',
#    'PLACE_NAME': '압구정로 342'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0416753',
#    'INSTL_Y': '37.527246',
#    'PLACE_NAME': '압구정로 410'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.033316',
#    'INSTL_Y': '37.528993',
#    'PLACE_NAME': '압구정로 주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0218102',
#    'INSTL_Y': '37.5224117',
#    'PLACE_NAME': '압구정로10길 18'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0220585',
#    'INSTL_Y': '37.5206204',
#    'PLACE_NAME': '압구정로10길 44'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0233984',
#    'INSTL_Y': '37.523409',
#    'PLACE_NAME': '압구정로14길 15'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0242918',
#    'INSTL_Y': '37.5231945',
#    'PLACE_NAME': '압구정로18길 28 '},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0488223',
#    'INSTL_Y': '37.5251001',
#    'PLACE_NAME': '압구정로79길 20'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0287240',
#    'INSTL_Y': '37.5266200',
#    'PLACE_NAME': '압구정역2번출구'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0281790',
#    'INSTL_Y': '37.5246390',
#    'PLACE_NAME': '압구정역4번출구'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0265910',
#    'INSTL_Y': '37.5260790',
#    'PLACE_NAME': '압구정역5번출구'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0349874',
#    'INSTL_Y': '37.5013003',
#    'PLACE_NAME': '앰배서더호텔'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0824159',
#    'INSTL_Y': '37.4897097',
#    'PLACE_NAME': '양재대로29길 6'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0474030',
#    'INSTL_Y': '37.4816970',
#    'PLACE_NAME': '양재천변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0493320',
#    'INSTL_Y': '37.4836040',
#    'PLACE_NAME': '양재천변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0636620',
#    'INSTL_Y': '37.4899480',
#    'PLACE_NAME': '양재천변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0700010',
#    'INSTL_Y': '37.4942720',
#    'PLACE_NAME': '양재천변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0724420',
#    'INSTL_Y': '37.4991920',
#    'PLACE_NAME': '양재천변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0735640',
#    'INSTL_Y': '37.5004850',
#    'PLACE_NAME': '양재천변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0745950',
#    'INSTL_Y': '37.4981000',
#    'PLACE_NAME': '양재천변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0341636',
#    'INSTL_Y': '37.5282597',
#    'PLACE_NAME': '언주로 872'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.032879',
#    'INSTL_Y': '37.524367',
#    'PLACE_NAME': '언주로 주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.033031',
#    'INSTL_Y': '37.523042',
#    'PLACE_NAME': '언주로 주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.033174',
#    'INSTL_Y': '37.526466',
#    'PLACE_NAME': '언주로 주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.033486',
#    'INSTL_Y': '37.528502',
#    'PLACE_NAME': '언주로 주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.033494',
#    'INSTL_Y': '37.521853',
#    'PLACE_NAME': '언주로 주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.033955',
#    'INSTL_Y': '37.528434',
#    'PLACE_NAME': '언주로 주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.035078',
#    'INSTL_Y': '37.523127',
#    'PLACE_NAME': '언주로 주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0254088',
#    'INSTL_Y': '37.5041793',
#    'PLACE_NAME': '역삼동 808-3'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0305758',
#    'INSTL_Y': '37.4984400',
#    'PLACE_NAME': '역삼세무서앞'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0349213',
#    'INSTL_Y': '37.5005961',
#    'PLACE_NAME': '역삼역4번출구'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0350011',
#    'INSTL_Y': '37.50044182',
#    'PLACE_NAME': '역삼역주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0358612',
#    'INSTL_Y': '37.50000054',
#    'PLACE_NAME': '역삼역주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0283960',
#    'INSTL_Y': '37.5208390',
#    'PLACE_NAME': '을지병원사거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0855778',
#    'INSTL_Y': '37.4914586',
#    'PLACE_NAME': '일원1동 658'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0774436',
#    'INSTL_Y': '37.4899302',
#    'PLACE_NAME': '일원동 690'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0824159',
#    'INSTL_Y': '37.4897097',
#    'PLACE_NAME': '일원동 맛의거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0851065',
#    'INSTL_Y': '37.4905227',
#    'PLACE_NAME': '일원동 맛의거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.075435',
#    'INSTL_Y': '37.489606',
#    'PLACE_NAME': '일원로 주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.077215',
#    'INSTL_Y': '37.489267',
#    'PLACE_NAME': '일원로 주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.080745',
#    'INSTL_Y': '37.490842',
#    'PLACE_NAME': '일원로 주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0851065',
#    'INSTL_Y': '37.4905227',
#    'PLACE_NAME': '일원로9길 45'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0753820',
#    'INSTL_Y': '37.4895520',
#    'PLACE_NAME': '일원초 정문'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0771130',
#    'INSTL_Y': '37.4892140',
#    'PLACE_NAME': '일원초 후문'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0330300',
#    'INSTL_Y': '37.5229910',
#    'PLACE_NAME': '제주항'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0493250',
#    'INSTL_Y': '37.5024180',
#    'PLACE_NAME': '진선여중'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0410333',
#    'INSTL_Y': '37.5196599',
#    'PLACE_NAME': '청담동 23-11'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0402600',
#    'INSTL_Y': '37.5240980',
#    'PLACE_NAME': '청담동거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0429330',
#    'INSTL_Y': '37.5245410',
#    'PLACE_NAME': '청담동거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0429340',
#    'INSTL_Y': '37.5239000',
#    'PLACE_NAME': '청담동거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0434540',
#    'INSTL_Y': '37.5263260',
#    'PLACE_NAME': '청담동거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0444110',
#    'INSTL_Y': '37.5249950',
#    'PLACE_NAME': '청담동거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0459810',
#    'INSTL_Y': '37.5249180',
#    'PLACE_NAME': '청담동거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0487210',
#    'INSTL_Y': '37.5246040',
#    'PLACE_NAME': '청담동거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0505020',
#    'INSTL_Y': '37.5248230',
#    'PLACE_NAME': '청담동거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0390419',
#    'INSTL_Y': '37.52381657',
#    'PLACE_NAME': '청담패션거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0394622',
#    'INSTL_Y': '37.52468715',
#    'PLACE_NAME': '청담패션거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0397613',
#    'INSTL_Y': '37.52569961',
#    'PLACE_NAME': '청담패션거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0398208',
#    'INSTL_Y': '37.52499634',
#    'PLACE_NAME': '청담패션거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0401061',
#    'INSTL_Y': '37.52685569',
#    'PLACE_NAME': '청담패션거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0403004',
#    'INSTL_Y': '37.5264152',
#    'PLACE_NAME': '청담패션거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.060235',
#    'INSTL_Y': '37.513526',
#    'PLACE_NAME': '코엑스 경제무역의거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.060958',
#    'INSTL_Y': '37.512165',
#    'PLACE_NAME': '코엑스 경제무역의거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.062297',
#    'INSTL_Y': '37.511223',
#    'PLACE_NAME': '코엑스 경제무역의거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.063015',
#    'INSTL_Y': '37.509876',
#    'PLACE_NAME': '코엑스 경제무역의거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.064196',
#    'INSTL_Y': '37.509442',
#    'PLACE_NAME': '코엑스 경제무역의거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0610880',
#    'INSTL_Y': '37.5118100',
#    'PLACE_NAME': '코엑스아트홀앞'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0601080',
#    'INSTL_Y': '37.5135870',
#    'PLACE_NAME': '코엑스아티움'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0602430',
#    'INSTL_Y': '37.5104500',
#    'PLACE_NAME': '코엑스주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0617800',
#    'INSTL_Y': '37.5105350',
#    'PLACE_NAME': '코엑스주변'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0262830',
#    'INSTL_Y': '37.5199580',
#    'PLACE_NAME': '태화빌딩'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0330480',
#    'INSTL_Y': '37.5222140',
#    'PLACE_NAME': '테일러메이드'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.03518',
#    'INSTL_Y': '37.501172',
#    'PLACE_NAME': '테헤란로 '},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.036453',
#    'INSTL_Y': '37.50228',
#    'PLACE_NAME': '테헤란로 '},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0515759',
#    'INSTL_Y': '37.5045005',
#    'PLACE_NAME': '테헤란로64길 9'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0317130',
#    'INSTL_Y': '37.4973760',
#    'PLACE_NAME': '테헤란로8길'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0544580',
#    'INSTL_Y': '37.5065940',
#    'PLACE_NAME': '포스코사거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0364540',
#    'INSTL_Y': '37.5022440',
#    'PLACE_NAME': '하나은행'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0278896',
#    'INSTL_Y': '37.5128022',
#    'PLACE_NAME': '학동로 156'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0446616',
#    'INSTL_Y': '37.5181174',
#    'PLACE_NAME': '학동로 411'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0389540',
#    'INSTL_Y': '37.5234010',
#    'PLACE_NAME': '학동사거리'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0622240',
#    'INSTL_Y': '37.5113920',
#    'PLACE_NAME': '한전앞'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0357230',
#    'INSTL_Y': '37.5223910',
#    'PLACE_NAME': '호림아트센터'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '강남구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.0334550',
#    'INSTL_Y': '37.5284450',
#    'PLACE_NAME': '호산병원'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.1411309',
#    'INSTL_Y': '37.5457181',
#    'PLACE_NAME': '강동구민회관'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.123762',
#    'INSTL_Y': '37.530127',
#    'PLACE_NAME': '강동구청'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1239762',
#    'INSTL_Y': '37.5306608',
#    'PLACE_NAME': '강동구청별관'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '강동구',
#    'INSTL_DIV': '상수도사업본부',
#    'INSTL_X': '127.1260331',
#    'INSTL_Y': '37.5290012',
#    'PLACE_NAME': '강동수도사업소'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1269',
#    'INSTL_Y': '37.52931',
#    'PLACE_NAME': '게네어린이공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1319',
#    'INSTL_Y': '37.54564',
#    'PLACE_NAME': '고분다리공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1254',
#    'INSTL_Y': '37.55027',
#    'PLACE_NAME': '광나루어린이공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.1646792',
#    'INSTL_Y': '37.5616221',
#    'PLACE_NAME': '동명그린공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.1647095',
#    'INSTL_Y': '37.5616726',
#    'PLACE_NAME': '동명그린공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.1647096',
#    'INSTL_Y': '37.5616708',
#    'PLACE_NAME': '동명그린공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1524',
#    'INSTL_Y': '37.5585',
#    'PLACE_NAME': '두레근린공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1359',
#    'INSTL_Y': '37.55352',
#    'PLACE_NAME': '볕우물어린이공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1314',
#    'INSTL_Y': '37.52501',
#    'PLACE_NAME': '보람어린이공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1309',
#    'INSTL_Y': '37.55203',
#    'PLACE_NAME': '새장터어린이공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1307',
#    'INSTL_Y': '37.55598',
#    'PLACE_NAME': '선사어린이공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1238',
#    'INSTL_Y': '37.52691',
#    'PLACE_NAME': '성내천어린이공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1265',
#    'INSTL_Y': '37.52983',
#    'PLACE_NAME': '성내하늬근린공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1269',
#    'INSTL_Y': '37.52926',
#    'PLACE_NAME': '성내하늬근린공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1456',
#    'INSTL_Y': '37.5496',
#    'PLACE_NAME': '염주골어린이공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.151',
#    'INSTL_Y': '37.533',
#    'PLACE_NAME': '일자산도시자연공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1361',
#    'INSTL_Y': '37.5449',
#    'PLACE_NAME': '천일어린이공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.133',
#    'INSTL_Y': '37.53894',
#    'PLACE_NAME': '천호3동어린이공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.125678',
#    'INSTL_Y': '37.543942',
#    'PLACE_NAME': '천호공원(도서관) '},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '127.125741',
#    'INSTL_Y': '37.544059',
#    'PLACE_NAME': '천호공원(도서관) '},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': '서울시',
#    'INSTL_X': '127.1222229',
#    'INSTL_Y': '37.54991223',
#    'PLACE_NAME': '한강안내센터(광나루)'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1539533',
#    'INSTL_Y': '37.5371085',
#    'PLACE_NAME': '허브천문공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.154',
#    'INSTL_Y': '37.537',
#    'PLACE_NAME': '허브천문공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.154',
#    'INSTL_Y': '37.538',
#    'PLACE_NAME': '허브천문공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1543259',
#    'INSTL_Y': '37.5376271',
#    'PLACE_NAME': '허브천문공원'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1333498',
#    'INSTL_Y': '37.5528446',
#    'PLACE_NAME': '강동구립암사도서관'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1255997',
#    'INSTL_Y': '37.5439721',
#    'PLACE_NAME': '강동구립해공도서관'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.1537484',
#    'INSTL_Y': '37.5360398',
#    'PLACE_NAME': '강동그린웨이가족캠프장'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '127.1739075',
#    'INSTL_Y': '37.5650410',
#    'PLACE_NAME': '도서관 강일도서관'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1333587',
#    'INSTL_Y': '37.5328694',
#    'PLACE_NAME': '성내도서관'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.130348',
#    'INSTL_Y': '37.5606377',
#    'PLACE_NAME': '암사동선사유적지'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.131',
#    'INSTL_Y': '37.56',
#    'PLACE_NAME': '암사선사유적지'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.1318501',
#    'INSTL_Y': '37.5613872',
#    'PLACE_NAME': '암사선사유적지'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '강동구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '127.131858',
# ...
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.887536',
#    'INSTL_Y': '37.495472',
#    'PLACE_NAME': '구로구청 본관'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.887536',
#    'INSTL_Y': '37.495472',
#    'PLACE_NAME': '구로구청 신관'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.887',
#    'INSTL_Y': '37.495',
#    'PLACE_NAME': '구로구청 앞'},
#   {'CATEGORY': '공공기관',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8395892',
#    'INSTL_Y': '37.4773788',
#    'PLACE_NAME': '남부구치소 민원실'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.855143',
#    'INSTL_Y': '37.491774',
#    'PLACE_NAME': '가린열북카페'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.852877',
#    'INSTL_Y': '37.489969',
#    'PLACE_NAME': '개웅어린이공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8886461',
#    'INSTL_Y': '37.50317783',
#    'PLACE_NAME': '거리공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8889418',
#    'INSTL_Y': '37.5028405',
#    'PLACE_NAME': '거리공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8909842',
#    'INSTL_Y': '37.5',
#    'PLACE_NAME': '거리공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.892408',
#    'INSTL_Y': '37.49857559',
#    'PLACE_NAME': '거리공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.85213',
#    'INSTL_Y': '37.505183',
#    'PLACE_NAME': '고척근린공원 농구장 옆'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.853486',
#    'INSTL_Y': '37.506077',
#    'PLACE_NAME': '고척근린공원 뒷문'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.850487',
#    'INSTL_Y': '37.506857',
#    'PLACE_NAME': '고척근린공원 산 정상'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.85245',
#    'INSTL_Y': '37.506368',
#    'PLACE_NAME': '고척근린공원 운동장'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.851966',
#    'INSTL_Y': '37.504085',
#    'PLACE_NAME': '고척근린공원 정문 앞'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.852875',
#    'INSTL_Y': '37.505936',
#    'PLACE_NAME': '고척근린공원 화장실 앞'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8518866',
#    'INSTL_Y': '37.50541606',
#    'PLACE_NAME': '고척근린공원1-1'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8526832',
#    'INSTL_Y': '37.50429048',
#    'PLACE_NAME': '고척근린공원1-3'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.853528',
#    'INSTL_Y': '37.50532138',
#    'PLACE_NAME': '고척근린공원1-4'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.892',
#    'INSTL_Y': '37.491',
#    'PLACE_NAME': '구로리공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.829',
#    'INSTL_Y': '37.501',
#    'PLACE_NAME': '궁동생태공원1'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.829',
#    'INSTL_Y': '37.502',
#    'PLACE_NAME': '궁동생태공원2'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.888753',
#    'INSTL_Y': '37.5101693',
#    'PLACE_NAME': '미래사랑어린이공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.889177',
#    'INSTL_Y': '37.51035441',
#    'PLACE_NAME': '미래사랑어린이공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.8249',
#    'INSTL_Y': '37.49645',
#    'PLACE_NAME': '삭새어린이공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.825587',
#    'INSTL_Y': '37.496126',
#    'PLACE_NAME': '삭새어린이공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.891',
#    'INSTL_Y': '37.508',
#    'PLACE_NAME': '신도림테크노근린공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.838031',
#    'INSTL_Y': '37.485893',
#    'PLACE_NAME': '오동나무어린이공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '126.84',
#    'INSTL_Y': '37.502',
#    'PLACE_NAME': '온수도시자연공원1'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '126.841',
#    'INSTL_Y': '37.502',
#    'PLACE_NAME': '온수도시자연공원1'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '126.838',
#    'INSTL_Y': '37.502',
#    'PLACE_NAME': '온수도시자연공원2'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '126.839',
#    'INSTL_Y': '37.502',
#    'PLACE_NAME': '온수도시자연공원2'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '126.825',
#    'INSTL_Y': '37.495',
#    'PLACE_NAME': '온수도시자연공원3'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.838401',
#    'INSTL_Y': '37.49816',
#    'PLACE_NAME': '체육소공원 '},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.838901',
#    'INSTL_Y': '37.49796',
#    'PLACE_NAME': '체육소공원 '},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.880101',
#    'INSTL_Y': '37.497531',
#    'PLACE_NAME': '화원어린이공원'},
#   {'CATEGORY': '공원',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.880323',
#    'INSTL_Y': '37.497784',
#    'PLACE_NAME': '화원어린이공원'},
#   {'CATEGORY': '광장',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.858765',
#    'INSTL_Y': '37.495296',
#    'PLACE_NAME': '개봉역 북부광장'},
#   {'CATEGORY': '광장',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '126.844',
#    'INSTL_Y': '37.495',
#    'PLACE_NAME': '오류동역앞 광장'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8901697',
#    'INSTL_Y': '37.4871528',
#    'PLACE_NAME': '구로꿈마을도서관'},
#   {'CATEGORY': '문화시설',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8809964',
#    'INSTL_Y': '37.4874572',
#    'PLACE_NAME': '하늘도서관(구로동)'},
#   {'CATEGORY': '버스승차대',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.902069',
#    'INSTL_Y': '37.484751',
#    'PLACE_NAME': '구로디지털단지역3'},
#   {'CATEGORY': '버스승차대',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.892227',
#    'INSTL_Y': '37.490155',
#    'PLACE_NAME': '영서중학교 파출소'},
#   {'CATEGORY': '버스승차대',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.843333',
#    'INSTL_Y': '37.495673',
#    'PLACE_NAME': '오류동역'},
#   {'CATEGORY': '보건시설',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.8894497',
#    'INSTL_Y': '37.5000533',
#    'PLACE_NAME': '구로구보건소'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '126.883478',
#    'INSTL_Y': '37.4913742',
#    'PLACE_NAME': '구로 드림스타트센터'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8907600',
#    'INSTL_Y': '37.4868115',
#    'PLACE_NAME': '구로종합사회복지관'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8907801',
#    'INSTL_Y': '37.48697299',
#    'PLACE_NAME': '구로종합사회복지관'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '126.8516476',
#    'INSTL_Y': '37.48502516',
#    'PLACE_NAME': '구로행복한청소년센터'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8296781',
#    'INSTL_Y': '37.49899852',
#    'PLACE_NAME': '궁동종합사회복지관'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '126.8502668',
#    'INSTL_Y': '37.49393482',
#    'PLACE_NAME': '섬기는지역아동센터'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8907163',
#    'INSTL_Y': '37.48106322',
#    'PLACE_NAME': '성프란치스꼬장애인종합복지관'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8446526',
#    'INSTL_Y': '37.49259093',
#    'PLACE_NAME': '오류애육원'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '126.8233172',
#    'INSTL_Y': '37.49672495',
#    'PLACE_NAME': '온수어르신복지관'},
#   {'CATEGORY': '복지시설',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '126.880144',
#    'INSTL_Y': '37.49733507',
#    'PLACE_NAME': '화원종합사회복지관'},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.889301',
#    'INSTL_Y': '37.48214',
#    'PLACE_NAME': '가리봉시장'},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '126.853825',
#    'INSTL_Y': '37.491793',
#    'PLACE_NAME': '개봉중앙시장'},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8510268',
#    'INSTL_Y': '37.5020549',
#    'PLACE_NAME': '개봉프라자'},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.851036',
#    'INSTL_Y': '37.502514',
#    'PLACE_NAME': '고척근린시장2-1'},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.8856',
#    'INSTL_Y': '37.489542',
#    'PLACE_NAME': '구로시장 '},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '시장상인회',
#    'INSTL_X': '126.8676342',
#    'INSTL_Y': '37.49024',
#    'PLACE_NAME': '남구로시장'},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '시장상인회',
#    'INSTL_X': '126.8681979',
#    'INSTL_Y': '37.4900471',
#    'PLACE_NAME': '남구로시장'},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '시장상인회',
#    'INSTL_X': '126.8699533',
#    'INSTL_Y': '37.4900978',
#    'PLACE_NAME': '남구로시장'},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '시장상인회',
#    'INSTL_X': '126.8855535',
#    'INSTL_Y': '37.4898736',
#    'PLACE_NAME': '남구로시장'},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '시장상인회',
#    'INSTL_X': '126.8863049',
#    'INSTL_Y': '37.4893749',
#    'PLACE_NAME': '남구로시장'},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '시장상인회',
#    'INSTL_X': '126.8863765',
#    'INSTL_Y': '37.4898019',
#    'PLACE_NAME': '남구로시장'},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '시장상인회',
#    'INSTL_X': '126.8866356',
#    'INSTL_Y': '37.4900074',
#    'PLACE_NAME': '남구로시장'},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '시장상인회',
#    'INSTL_X': '126.8878063',
#    'INSTL_Y': '37.4896513',
#    'PLACE_NAME': '남구로시장'},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.88556',
#    'INSTL_Y': '37.490208',
#    'PLACE_NAME': '남구로시장 '},
#   {'CATEGORY': '전통시장',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.844',
#    'INSTL_Y': '37.496',
#    'PLACE_NAME': '오류시장'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.8936094',
#    'INSTL_Y': '37.4813921',
#    'PLACE_NAME': '가리봉동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.8511255',
#    'INSTL_Y': '37.5003318',
#    'PLACE_NAME': '개봉1동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.8511255',
#    'INSTL_Y': '37.5003318',
#    'PLACE_NAME': '개봉1동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.85655',
#    'INSTL_Y': '37.490851',
#    'PLACE_NAME': '개봉2동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.8565500',
#    'INSTL_Y': '37.4908510',
#    'PLACE_NAME': '개봉2동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.853838',
#    'INSTL_Y': '37.485993',
#    'PLACE_NAME': '개봉3동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.8538380',
#    'INSTL_Y': '37.4859930',
#    'PLACE_NAME': '개봉3동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.862747',
#    'INSTL_Y': '37.5004171',
#    'PLACE_NAME': '고척1동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.8627470',
#    'INSTL_Y': '37.5004171',
#    'PLACE_NAME': '고척1동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '126.8587122',
#    'INSTL_Y': '37.5067055',
#    'PLACE_NAME': '고척2동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.8587122',
#    'INSTL_Y': '37.5067055',
#    'PLACE_NAME': '고척2동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.8757585',
#    'INSTL_Y': '37.4930433',
#    'PLACE_NAME': '구로1동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8834703',
#    'INSTL_Y': '37.4913771',
#    'PLACE_NAME': '구로2동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.8834703',
#    'INSTL_Y': '37.4913771',
#    'PLACE_NAME': '구로2동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '126.8903678',
#    'INSTL_Y': '37.4873799',
#    'PLACE_NAME': '구로3동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.8903678',
#    'INSTL_Y': '37.4873799',
#    'PLACE_NAME': '구로3동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8891488',
#    'INSTL_Y': '37.4915766',
#    'PLACE_NAME': '구로4동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.8891488',
#    'INSTL_Y': '37.4915766',
#    'PLACE_NAME': '구로4동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.8892945',
#    'INSTL_Y': '37.5001593',
#    'PLACE_NAME': '구로5동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.8892945',
#    'INSTL_Y': '37.5001593',
#    'PLACE_NAME': '구로5동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.8314627',
#    'INSTL_Y': '37.4939422',
#    'PLACE_NAME': '수궁동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.8314627',
#    'INSTL_Y': '37.4939422',
#    'PLACE_NAME': '수궁동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8805826',
#    'INSTL_Y': '37.5077664',
#    'PLACE_NAME': '신도림동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.8805826',
#    'INSTL_Y': '37.5077664',
#    'PLACE_NAME': '신도림동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8450239',
#    'INSTL_Y': '37.4970673',
#    'PLACE_NAME': '오류1동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.8450239',
#    'INSTL_Y': '37.4970673',
#    'PLACE_NAME': '오류1동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'SKT',
#    'INSTL_X': '126.8395371',
#    'INSTL_Y': '37.4888016',
#    'PLACE_NAME': '오류2동주민센터'},
#   {'CATEGORY': '주민센터',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.8395371',
#    'INSTL_Y': '37.4888016',
#    'PLACE_NAME': '오류2동주민센터'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'KT',
#    'INSTL_X': '126.851967',
#    'INSTL_Y': '37.493542',
#    'PLACE_NAME': '개봉경로당'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '126.9',
#    'INSTL_Y': '37.486',
#    'PLACE_NAME': '구로디지탈단지역앞1'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '126.902',
#    'INSTL_Y': '37.484',
#    'PLACE_NAME': '구로디지탈단지역앞2'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.892026612618',
#    'INSTL_Y': '37.4834881386147',
#    'PLACE_NAME': '구로디지털단지'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.892481192742',
#    'INSTL_Y': '37.4858131540321',
#    'PLACE_NAME': '구로디지털단지'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '구로구',
#    'INSTL_DIV': 'LGU+',
#    'INSTL_X': '126.8924936',
#    'INSTL_Y': '37.48579429',
#    'PLACE_NAME': '구로디지털단지'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.892556590185',
#    'INSTL_Y': '37.4844842358033',
#    'PLACE_NAME': '구로디지털단지'},
#   {'CATEGORY': '주요거리',
#    'GU_NM': '구로구',
#    'INSTL_DIV': '구로구',
#    'INSTL_X': '126.893040453924',
#    'INSTL_Y': '37.4821465583013',
#    'PLACE_NAME': '구로디지털단지'},
#   ...],
#  'DESCRIPTION': {'CATEGORY': '유형',
#   'GU_NM': '구명',
#   'INSTL_DIV': '설치기관(회사)',
#   'INSTL_X': '설치위치(X좌표)',
#   'INSTL_Y': '설치위치(Y좌표)',
#   'PLACE_NAME': '지역명'}}

# %%
textlines = text.splitlines()
textlines[:5]

# %% [markdown]
# * 가장 먼저 해야 할 일은 JSON 조작을 위해 json 모듈을 임포트하는 것이다.
# * 예제 파일 전체가 하나의 JSON 문자열이므로 파일의 내용 전체를 한 번에 읽어야 한다. 파일 객체의 `read()` 메소드를 이용한다.
# * JSON 문자열을 딕셔너리 형의 JSON 객체로 만들기 위해 json 모듈의 `loads()` 함수를 사용한다.
#
# 이번에는 반대로 파이썬 딕셔너리를 JSON 문자열로 바꾸는 과정을 살펴보자.

# %%
# 딕셔너리를 JSON 문자열로 만들기
import json

dogs = {
    "description": "반려견의 종별 특징",
    "data": [
        {
            "name": "코카스파니엘",
            "feature": "귀여운 외모, 아름다운 털, 환경에 잘 적응, 30cm 중반대"
        },
        {
            "name": "포메리안",
            "feature": "부드러운 털, 말 잘 들으나 흥분 쉽게 함, 26-27cm 이내"
        },
        {
            "name": "비글",
            "feature": "악마견, 귀여운 외모, 총명함"
        }
    ]
}

esc_str = json.dumps(dogs)  # json type 즉,dictionary type을 스트링 타입으로 만든다.
print(esc_str)

unesc_str = json.dumps(dogs, ensure_ascii=False) # json타입을 한글이 readable하게 스트링으로 변환한다
print(unesc_str)
# Out:
# {"description": "\ubc18\ub824\uacac\uc758 \uc885\ubcc4 \ud2b9\uc9d5", "data": [{"name": "\ucf54\uce74\uc2a4\ud30c\ub2c8\uc5d8", "feature": "\uadc0\uc5ec\uc6b4 \uc678\ubaa8, \uc544\ub984\ub2e4\uc6b4 \ud138, \ud658\uacbd\uc5d0 \uc798 \uc801\uc751, 30cm \uc911\ubc18\ub300"}, {"name": "\ud3ec\uba54\ub9ac\uc548", "feature": "\ubd80\ub4dc\ub7ec\uc6b4 \ud138, \ub9d0 \uc798 \ub4e4\uc73c\ub098 \ud765\ubd84 \uc27d\uac8c \ud568, 26-27cm \uc774\ub0b4"}, {"name": "\ube44\uae00", "feature": "\uc545\ub9c8\uacac, \uadc0\uc5ec\uc6b4 \uc678\ubaa8, \ucd1d\uba85\ud568"}]}
# {"description": "반려견의 종별 특징", "data": [{"name": "코카스파니엘", "feature": "귀여운 외모, 아름다운 털, 환경에 잘 적응, 30cm 중반대"}, {"name": "포메리안", "feature": "부드러운 털, 말 잘 들으나 흥분 쉽게 함, 26-27cm 이내"}, {"name": "비글", "feature": "악마견, 귀여운 외모, 총명함"}]}

# %%
dogs
# Out:
# {'data': [{'feature': '귀여운 외모, 아름다운 털, 환경에 잘 적응, 30cm 중반대', 'name': '코카스파니엘'},
#   {'feature': '부드러운 털, 말 잘 들으나 흥분 쉽게 함, 26-27cm 이내', 'name': '포메리안'},
#   {'feature': '악마견, 귀여운 외모, 총명함', 'name': '비글'}],
#  'description': '반려견의 종별 특징'}

# %%
type(dogs)
# Out:
# dict

# %% [markdown]
# * `loads()` 함수와 대비되며 파이썬 객체를 JSON 문자열로 바꾸는 함수는 `dumps()` 함수이다.
# * `dumps()` 함수는 정수, 문자열, 리스트 등 많은 형의 객체를 JSON 문자열로 바꿀 수 있지만 일반적으로 딕셔너리를 이용한다.
# * JSON 표준을 엄격하게 적용하면 한글 등 ASCII 문자로 표현할 수 없는 문자는 이스케이핑을 해야 하지만, 기준을 완화하여 ASCII 문자가 아닌 문자도 이스케이핑하지 않고 표시하도록 하는 것이 편리하다.

# %% [markdown]
# ### JSON 라인 파일
# 앞서 살펴본 JSON 파일은 파일의 내용 전체가 하나의 JSON 객체에 해당한다. 한편 줄 단위로 JSON 문자열을 저장한 파일도 많이 쓰이는데 이를 JSON 라인 파일(JSON lines text file format, <http://jsonlines.org>)이라 부른다. 다음은 `seoul_wifi.json` 파일을 가공하여 JSON 라인 파일로 만든 `seoul_wifi.jsonl` 파일의 내용의 일부이다.

# %% [markdown]
# ```json
# {"PLACE_NAME":"(재)서울산업통상진흥원","CATEGORY":"공공기관","INSTL_X":"127.0717546","INSTL_Y":"37.4955815","GU_NM":"강남구","INSTL_DIV":"LGU+"}
# {"PLACE_NAME":"(재)서울산업통상진흥원서울신기술창업센타","CATEGORY":"공공기관","INSTL_X":"127.0380541","INSTL_Y":"37.4976121","GU_NM":"강남구","INSTL_DIV":"LGU+"}
# {"PLACE_NAME":"U강남도시관제센터","CATEGORY":"공공기관","INSTL_X":"127.0409920","INSTL_Y":"37.5084025","GU_NM":"강남구","INSTL_DIV":"강남구"}
# ...
# ```

# %% [markdown]
# JSON 라인 형식은 각 줄이 JSON 문자열로 이루어져 있고 각 줄의 구분은 당연히 줄바꿈 문자로 한다. 각 줄의 끝에 `,`가 있으면 안된다는 것을 잊지 말자. 이제 이 파일을 읽어서 파이썬 객체를 생성하는 예제를 살펴보자.

# %%
# JSON 라인 파일 읽기
import json

data = []
file_name = "../data/textproc/seoul_wifi.jsonl"

with open(file_name, "r", encoding="utf-8") as input_file:
    for line in input_file:
        datum = json.loads(line)
        data.append(datum)

# %% [markdown]
# 위의 예제는 JSON 라인 파일을 줄 단위로 읽어서 객체를 만들어 리스트에 추가하는 전형적인 예이다. 각 줄의 구분자인 줄바꿈 문자를 `strip()` 메소드를 이용하여 없애주지 않아도 딕녀너리 객체가 제대로 만들어진다.

# %%
# JSON 라인 파일 쓰기
import json

data = [
    {
        "name": "코카스파니엘",
        "feature": "귀여운 외모, 아름다운 털, 환경에 잘 적응, 30cm 중반대"
    },
    {
        "name": "포메리안",
        "feature": "부드러운 털, 말 잘 들으나 흥분 쉽게 함, 26-27cm 이내"
    },
    {
        "name": "비글",
        "feature": "악마견, 귀여운 외모, 총명함"
    }
]

file_name = "../data/textproc/dogs.txt"

with open(file_name, "w", encoding="utf-8") as output_file:
    for datum in data:
        line = json.dumps(datum, ensure_ascii=False)
        print(line, file=output_file)

# %% [markdown]
# >JSON 파일과 JSON 라인 파일의 확장자로 `json`과 `jsonl`을 사용하였는데 반드시 그렇게 해야하는 것은 아니다.

# %% [markdown]
# >현장에서는 표준 모듈인 json보다 훨씬 속도가 빠른 ujson 모듈을 많이 사용한다. ujson 모듈은 표준 모듈은 아니지만 쉽게 설치할 수 있다.

# %% [markdown]
# ## 비정형 텍스트 파일 처리
#
# ### 예제 파일
# 예제 비정형 파일로는 인터넷에서 구한 이청준의 단편 소설 "벌레 이야기" 파일을 사용한다. 이 파일은 앞서와 마찬가지로 `data\textproc` 디렉토리에 들어 있다.
#
# 이 파일은 정형적인 비정형 텍스트 파일로 대체로 하나의 줄이 하나의 단락으로 구성되어 있는 것 외에는 별다른 외현적 구조를 가지고 있지 않다. 맨 윗줄이 소설의 제목이고 숫자로만 이루어진 단락은 장 혹은 절 구분이라는 구조는 암묵적으로 주어져 있다.
#
# >요즘에는 문장의 중간, 심지어 한 어절의 중간에서 물리적인 줄바꿈이 이루어진 텍스트 파일이 그리 많지 않다. 어절이 잘린 텍스트 파일을 제대로 처리하기 위해서는 상당히 번거로운 전처리 과정이 필요하다.
#
# ### 어절의 분절과 계수
# 한국어에서 어절은 일반적으로 공백 문자로 구분된 문자열로 정의한다. 그러므로 어절의 분절은 문자열의 `split()` 메소드를 이용하여 다음과 같이 할 수 있다.

# %%
# 어절의 분절
input_file_name = "../data/textproc/worm.txt"

with open(input_file_name, "r", encoding="utf-8") as input_file:
    for line in input_file:
        line = line.strip()  # newline character를 제거
        wordforms = line.split()
        
        for wordform in wordforms:
            print(wordform)

# %% [markdown]
# 이제 분절된 어절의 빈도를 세보자. 빈도를 세는 데에는 보통 딕셔너리를 사용한다. 이 때 각 어절이 딕셔너리의 키가 되고 해당 어절의 빈도가 값이 된다. 텍스트 파일의 앞에서부터 순차적으로 누계가 이루어지면서 빈도가 갱신되어 파일의 모든 내용을 처리하고 나면 최종 빈도가 얻어진다. 최근에는 빈도 계수에 특화된 Counter 클래스를 딕셔너리 대신에 사용하는 것이 권장된다.

# %%
# 어절의 계수

from collections import Counter

input_file_name = "../data/textproc/worm.txt"
wordform_counter = Counter()

with open(input_file_name, "r", encoding="utf-8") as input_file:
    for line in input_file:
        line = line.strip()
        wordforms = line.split()
        
        for wordform in wordforms:
            wordform_counter[wordform] += 1
       # wordform_counter.update(wordforms)     
for wordform, freq in wordform_counter.most_common():
    print("{}\t{}".format(wordform, freq))

# %% [markdown]
# * Counter 클래스는 앞서 사용한 defaultdict 클래스와 비슷하게 동작하여 빈도의 기본값인 0이 모든 키에 대해서 미리 상정된다.
# * Counter 클래스의 `most_common()` 메소드는 빈도 계수 결과를 빈도 역순으로 정렬하여 출력할 때에 매우 요긴하다.

# %% [markdown]
# ### 문장의 분절
# 문장은 텍스트 파일의 내재적 단위가 아니다. 즉, 문장과 문장을 구분하는 명시적인 구분자가존재하지 않는다. 언어학에서도 문장을 명확하게 정의하는 것은 그리 쉬운 일이 아니다. 텍스트 처리에서는 문장을 문장의 종결을 나타내는 문장 부호인 `.`, `?`, `!`로 구분하는 방법을 많이 사용한다. 그런데 이들 문장 부호가 때로 문장의 종결이 아닌 곳에서도 사용될 수 있기 때문에 이들 부호에 공백 문자가 연이어진 경우를 문장의 구분이 이루어지는 것으로 보는 것이 안전하다.  실제 구현에 있어서는 문장의 구분을 줄의 구분과 일치시켜서 문장의 구분이 텍스트 파일의 외현적 구조에 반영되도록 하는 것이 편리하다.

# %%
# 문장의 분절

input_file_name = "../data/textproc/worm.txt"
sentences = []

with open(input_file_name, "r", encoding="utf-8") as input_file:
    for line in input_file:
        line = line.strip()
        line = line.replace(". ", ".\n")
        line = line.replace("? ", "?\n")
        line = line.replace("! ", "!\n")
        sub_sentences = line.splitlines()
        sentences += sub_sentences   # 리스트끼리 더하는 형태. 
        #sentences.append(sub_sentences)  # 리스트를 원소로 append하는 형태. 리스트내 리스트 구조
        
for sentence in sentences:
    print(sentence)

# %% [markdown]
# * `replace()` 메소드를 사용하여 설정된 문장 구분을 줄의 구분으로 바꾼다.
# * 줄의 구분을 위해 `splitlines()` 메소드를 사용한다.
# * 전체 문장 리스트를 갱신하기 위해 `+=` 연산자를 리스트에 적용한다.
#
# >위의 방법은 같은 문자열에 대하여 여러번 문자열 치환 연산을 반복하기 때문에 효율적이지 못하다. 한 번의 경로(single path)로 문자열 치환이 이루어지는 방법(예: 정규식)을 이용하는 것이 효율적이다.
#
# 위의 문장 분절 부분은 분리하여 사용자 함수로 구성하는 것이 좋다.

# %%
# 문장의 분절
# 사용자 함수 작성

def split_sentences(text):
    text = text.strip().replace(". ", ".\n").replace("? ", "?\n").replace("! ", "!\n")
    sentences = text.splitlines()
    
    return sentences


input_file_name = "../data/textproc/worm.txt"
sentences = []

with open(input_file_name, "r", encoding="utf-8") as input_file:
    for line in input_file:
        sub_sentences = split_sentences(line)
        sentences += sub_sentences
        
for sentence in sentences:
    print(sentence)

# %% [markdown]
# 이 강좌에서는 정규식을 본격적으로 다루지 않지만 위의 함수를 정규식을 이용하여 효율적으로 바꾼 코드를 아래에 보인다.

# %%
# 문장의 분절
# 정규식을 이용한 문장 분절 함수 작성
import re

def split_sentences_re(text):
    sentences = re.split("(?<=[.?!]) ", text.strip())
    
    return sentences


input_file_name = "../data/textproc/worm.txt"
sentences = []

with open(input_file_name, "r", encoding="utf-8") as input_file:
    for line in input_file:
        sub_sentences = split_sentences_re(line)
        sentences += sub_sentences
        
for sentence in sentences:
    print(sentence)

# %%
m = re.search("\\wb", "abc def 123")
m.group(0)

# %% [markdown]
# # 연습 문제
# 1. 제공하는 `daily-weather-headlines.txt` 파일을 읽어서 월별 어절 빈도를 구조화하여 출력하라.
# 1. 빈도 상위 20 개의 어절에 대하여 스프레드시트에서 월별 빈도 차트를 그릴 수 있는 형태의 TSV 파일을 생성하라.

# %%
from collections import defaultdict, Counter
input_file_name = "../data/textproc/daily-weather-headlines.txt"


word_dic = defaultdict(list)
with open(input_file_name, "r", encoding="utf-8") as  input_file:
    for line in input_file:
        line = line.strip()
        wordforms = line.split()
        word_dic[wordforms[0]] += wordforms[1:]

# %%
month_keys = []
for day_key in list(word_dic.keys()):
    month_keys.append(day_key[:6])
month_keys = set(month_keys)

# %%
month_counter_dic = defaultdict(dict)
for month_key in month_keys:
    month_counter_dic[month_key] = Counter()

# %%
month_counter_dic['201608']

# %%
for key in word_dic:
    month_key = key[:6]
    month_counter_dic[month_key].update(word_dic[key])

# %%
month_counter_dic['201607']

# %%
month_counter_dic
